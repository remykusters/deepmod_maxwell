# %%
from phimal_utilities.analysis import load_tensorboard
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
path = 'runs/Jul12_06-36-28_9fa067350107/'

# %%
df = load_tensorboard(path)

# %%
plt.semilogy(df.index, df['MSE_0'][:])
plt.semilogy(df.index, df['Regression_0'])

# %%
coeff_keys = [key for key in df.keys() if key[:5]=='coeff']

# %%
un_coeff_keys = [key for key in df.keys() if key[:5]=='unsca']

# %%
coeff_keys
# Out:
# ['coeff_0_0',
#  'coeff_0_1',
#  'coeff_0_2',
#  'coeff_0_3',
#  'coeff_0_4',
#  'coeff_0_5',
#  'coeff_0_6']

# %%
plt.figure(figsize=(15, 5))
for idx, key in enumerate(coeff_keys):
    plt.plot(df[key][10:-1], label=f'{idx}')
#plt.ylim([-5, 10])
plt.legend(loc='lower left')
#plt.xlim([9500, 11000])

# %%
plt.figure(figsize=(15, 5))
for idx, key in enumerate(un_coeff_keys):
    plt.plot(df[key][:-1], label=f'{idx}')
#plt.ylim([-5, 10])
plt.legend(loc='lower left')
#plt.xlim([9500, 11000])

# %%
plt.semilogy(abs(df.iloc[-2][coeff_keys]), 'o')

# %%
plt.plot(df.iloc[-2][coeff_keys], 'o')

# %%
plt.plot(df.iloc[-2][un_coeff_keys], 'o')
